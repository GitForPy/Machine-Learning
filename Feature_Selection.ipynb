# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
import warnings
warnings.filterwarnings('ignore')

# %%
x_data_generated, y_data_generated = make_classification(scale=1)

# %%
x_data_generated[0]
# Out:
# array([ 0.95607296,  0.79431561,  0.06632269,  1.12840709, -0.17875524,
#        -0.25240327, -1.08897285, -0.1717277 ,  0.78464694, -0.12941478,
#         0.30229784,  0.77707848, -0.35565483, -0.6957207 ,  0.41294964,
#         0.02138345,  1.05082142,  0.20577741,  1.02745688, -0.57961018])

# %%
X = x_data_generated
y = y_data_generated

# %%
# skf = StratifiedKFold(5, shuffle=True, random_state=1) - для несбалансированных классов.

kf = KFold(5, shuffle=True, random_state=1)
cross_val_score(LogisticRegression(), X, y, cv=kf, scoring='accuracy').mean()
# Out:
# 0.74

# %%
df = pd.DataFrame(X)
df['Target'] = y
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.956073  0.794316  0.066323  1.128407 -0.178755 -0.252403 -1.088973
# 1  0.890187 -1.798588 -0.257090 -1.062394  1.444927 -0.625400  1.153566
# 2  0.809262  0.525801  0.914883 -1.784580  1.976858 -0.972320  2.203009
# 3 -1.090028 -1.102807  1.257973  2.462739 -3.907953 -0.406106  0.061506
# 4  1.022964 -0.760294  0.088643  1.158939 -0.670197 -1.022253  1.011382
#
#           7         8         9  ...        11        12        13        14  \
# 0 -0.171728  0.784647 -0.129415  ...  0.777078 -0.355655 -0.695721  0.412950
# 1  0.206360  0.613566 -0.349264  ... -1.085647 -0.975446 -0.902726 -0.470575
# 2  0.330879 -0.878193  0.375100  ... -0.645349  0.620448 -0.966928 -2.113015
# 3 -0.497909  0.422089 -2.118280  ... -1.396266 -0.008585  2.774050 -0.739984
# 4 -0.193404 -0.468887 -1.438804  ...  0.824443  0.842232 -0.120788  0.868467
#
#          15        16        17        18        19  Target
# 0  0.021383  1.050821  0.205777  1.027457 -0.579610       0
# 1  0.785216  0.641356  0.937373  0.441115  0.206173       0
# 2  0.744393  0.326435 -1.553509 -1.419554 -0.429619       0
# 3  0.258012 -1.611887 -0.631917  0.062640  0.207196       1
# 4  0.874607  0.223349 -0.670263  0.215650 -0.057629       0
#
# [5 rows x 21 columns]

# %%
conf_matrix = df.corr()
conf_matrix_target = conf_matrix['Target'].sort_values(ascending=False)

# %%
conf_matrix_target
# Out:
# Target    1.000000
# 13        0.686809
# 14        0.212348
# 15        0.100087
# 1         0.092728
# 9         0.088338
# 3         0.069457
# 11        0.069385
# 2         0.066388
# 5         0.060528
# 12        0.058156
# 6         0.021280
# 8         0.019557
# 10        0.010789
# 18        0.007436
# 16       -0.032825
# 19       -0.096379
# 0        -0.097670
# 7        -0.165236
# 17       -0.217414
# 4        -0.587145
# Name: Target, dtype: float64

# %%
plt.figure(figsize=(18, 15))
sns.heatmap(conf_matrix ,annot=True)
plt.show()

# %%
plt.figure(figsize=(5, 7))
sns.heatmap(conf_matrix.iloc[-1,:].sort_values(ascending=False).values.reshape(-1, 1).round(2), annot=True)
plt.show()

# %%
feature_importance_heat_map = abs(conf_matrix.iloc[-1,:]).sort_values(ascending=False)
feature_importance_heat_map = feature_importance_heat_map.reset_index()
feature_importance_heat_map
# Out:
#      index    Target
# 0   Target  1.000000
# 1       13  0.686809
# 2        4  0.587145
# 3       17  0.217414
# 4       14  0.212348
# 5        7  0.165236
# 6       15  0.100087
# 7        0  0.097670
# 8       19  0.096379
# 9        1  0.092728
# 10       9  0.088338
# 11       3  0.069457
# 12      11  0.069385
# 13       2  0.066388
# 14       5  0.060528
# 15      12  0.058156
# 16      16  0.032825
# 17       6  0.021280
# 18       8  0.019557
# 19      10  0.010789
# 20      18  0.007436

# %%
top_5_features = feature_importance_heat_map[feature_importance_heat_map['index'] != 'Target'].iloc[0:4]
top_5_features
# Out:
#   index    Target
# 1    13  0.686809
# 2     4  0.587145
# 3    17  0.217414
# 4    14  0.212348

# %%
X.shape
# Out:
# (100, 20)

# %%
list_top_5_feat = list(top_5_features['index'].values)
list_top_5_feat
# Out:
# [13, 4, 17, 14]

# %%
X_top_5 = X[:, [13, 4, 17, 14]]
X_top_5
# Out:
# array([[-6.95720697e-01, -1.78755238e-01,  2.05777406e-01,
#          4.12949641e-01],
#        [-9.02725739e-01,  1.44492682e+00,  9.37373224e-01,
#         -4.70575185e-01],
#        [-9.66927559e-01,  1.97685755e+00, -1.55350864e+00,
#         -2.11301483e+00],
#        [ 2.77404982e+00, -3.90795302e+00, -6.31916762e-01,
#         -7.39983968e-01],
#        [-1.20788188e-01, -6.70197258e-01, -6.70263279e-01,
#          8.68466785e-01],
#        [ 7.06460271e-01,  1.13964094e+00,  1.62767771e+00,
#         -1.06301897e+00],
#        [ 7.29045157e-01,  4.20775275e-01,  5.44849044e-01,
#          5.09807755e-01],
#        [-9.53597927e-01,  1.49051730e+00,  1.91555496e+00,
#         -2.09186724e+00],
#        [ 1.05765234e+00, -2.73674482e-01, -2.23955077e+00,
#         -4.24597460e-01],
#        [ 4.42114581e-01, -2.03550006e+00, -7.39042704e-01,
#         -1.81102117e+00],
#        [ 7.13732452e-01, -1.12123794e+00, -2.41354932e-01,
#          5.88868212e-01],
#        [-1.04528163e+00, -3.90929460e-01,  1.29893839e+00,
#          1.25053052e+00],
#        [ 1.16431740e+00, -5.02739587e-01, -1.54663278e+00,
#         -1.22002573e+00],
#        [-4.52835499e-01, -2.13945512e-01,  6.81681370e-01,
#         -2.89902412e-01],
#        [-1.93571859e-01,  1.37422150e+00, -8.99227175e-01,
#         -8.78371141e-01],
#        [ 1.99811962e+00, -1.84911546e+00, -1.50103184e+00,
#          2.48417154e-01],
#        [ 3.15409770e-01,  1.32374198e+00, -4.34907408e-02,
#          9.90693099e-01],
#        [ 1.67888611e+00, -2.82273713e+00,  2.47334725e-01,
#         -9.41703099e-01],
#        [-7.67966774e-01, -4.33075002e-01, -1.56100450e+00,
#          8.11633463e-01],
#        [-8.04052656e-01,  1.78402223e-01, -1.40655221e+00,
#          2.90957624e-01],
#        [-1.79332008e-01,  1.76299432e-01,  1.70138559e-01,
#         -2.64728832e-01],
#        [ 1.52507719e+00, -1.27480518e+00, -6.29801202e-01,
#         -2.57929562e+00],
#        [ 2.59860925e-01, -1.45934807e+00,  4.16230929e-01,
#          1.58380035e+00],
#        [-1.18319230e+00,  2.00068552e-01,  1.43616667e+00,
#          1.70792013e-01],
#        [-1.05417483e-01, -8.77414923e-01, -2.08800338e-01,
#          1.72757738e-01],
#        [-3.23587140e-01,  2.66073566e+00,  2.53480988e-01,
#          3.52884842e-01],
#        [-1.38343493e+00,  6.08706401e-01,  6.78948641e-02,
#          4.06243072e-02],
#        [-5.30844656e-02,  1.10705120e+00,  4.10484144e-01,
#          1.79253629e-01],
#        [ 1.67014883e+00, -1.58453135e+00,  1.34485595e+00,
#          1.93135196e+00],
#        [ 6.25185984e-02,  1.86141066e+00,  7.53952294e-01,
#          3.53275744e-01],
#        [ 9.50544022e-01, -5.12993207e-02, -1.64220029e-01,
#          2.32494300e+00],
#        [-1.56457868e+00,  4.71491040e-01, -4.98594639e-03,
#         -8.61317593e-01],
#        [-1.71470873e+00,  1.36031812e+00, -1.03077260e+00,
#         -7.27986993e-01],
#        [-9.93183855e-01,  4.02965847e-01,  4.66878400e-01,
#          8.09092284e-01],
#        [ 8.93879773e-01,  1.15472720e+00, -5.10589587e-01,
#          3.45561257e-01],
#        [-2.20466941e+00,  3.76087530e-01,  3.11483152e+00,
#          3.03254235e-01],
#        [-2.45470833e+00,  1.79948007e+00,  6.44139033e-01,
#         -1.07376282e+00],
#        [ 2.12146441e-01, -1.16970315e+00,  2.68844058e-02,
#          2.68555866e-01],
#        [ 1.55646804e+00, -1.36863341e+00,  1.11998593e+00,
#         -1.22637452e+00],
#        [-1.45790969e+00, -4.59091825e-01,  1.15421712e+00,
#          2.82572765e-01],
#        [-1.26240838e+00,  1.50681861e+00, -1.07444292e-01,
#         -1.13230613e+00],
#        [ 4.56350647e-01, -7.55292795e-01,  8.28862237e-01,
#          1.40494909e+00],
#        [-1.44429774e+00,  3.29883419e-01, -2.40699662e-01,
#         -7.72447177e-01],
#        [ 9.50897279e-01,  1.02871840e+00,  6.98826887e-01,
#          5.60587704e-01],
#        [-1.53289781e+00,  1.39873043e+00,  8.38708043e-01,
#          8.56095619e-02],
#        [ 1.35417182e+00, -9.29022419e-01,  7.60558474e-02,
#         -5.94760837e-01],
#        [ 2.60500392e-01, -1.02666727e+00,  1.36586335e+00,
#          4.29358259e-01],
#        [-1.06145378e+00, -1.18576252e-01, -1.34847355e+00,
#          1.10478013e-01],
#        [ 3.94989761e-01,  1.12102133e+00, -1.80177637e+00,
#         -1.26662215e-01],
#        [ 1.13020615e+00, -1.30382856e+00,  8.65343048e-03,
#          5.23482823e-01],
#        [ 6.36955721e-01,  1.38765112e+00,  8.07812332e-01,
#          3.21940665e-01],
#        [-8.54086286e-01, -4.56271508e-01,  4.73263755e-01,
#          2.34489223e-02],
#        [ 1.00546790e+00, -1.41713427e-01, -2.74627073e-01,
#         -6.88966944e-01],
#        [-1.19524655e+00,  5.39955409e-01,  1.39536303e-01,
#          9.57388367e-01],
#        [ 1.79580351e+00, -1.85702749e+00,  7.85911314e-01,
#         -1.05089430e+00],
#        [ 1.29854787e-01, -1.12356531e-01, -4.10960003e-01,
#         -1.12766992e-02],
#        [-9.13045088e-01,  2.10388333e-01, -2.98562648e-01,
#         -9.25045429e-01],
#        [ 5.42025348e-02, -3.27558468e-01, -8.89999865e-02,
#          1.47565056e+00],
#        [-8.02707864e-02,  5.92087649e-01,  8.51286029e-01,
#          1.47681059e+00],
#        [-1.74636641e-01,  1.18245764e+00,  1.28449320e+00,
#         -7.42194655e-02],
#        [-1.77619782e+00,  1.45114124e+00, -4.97036394e-01,
#          1.87361890e+00],
#        [ 1.59478175e+00, -8.47581955e-01, -1.59799577e+00,
#          1.92396043e-02],
#        [-1.15602197e+00,  1.39718173e+00,  3.61138254e-01,
#          1.14089227e+00],
#        [-8.51017590e-01,  1.45204786e-01,  5.51300155e-01,
#         -1.33870945e+00]])

# %%
kf = KFold(5, shuffle=True, random_state=1)
cross_val_score(LogisticRegression(), X_top_5, y, cv=kf, scoring='accuracy').mean()
# Out:
# 0.85
